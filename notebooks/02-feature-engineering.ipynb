# %%
import pandas as pd

# %%
file_path = '../data/processed/all_schools_cleaned.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#     student_id        full_name  gender  math_score  english_score  \
# 0     5506-350       Mary Smith    Male        92.0           14.0
# 1     2424-704       Mary Moore  Female        82.0           86.0
# 2     4582-338    James Johnson    Male        99.0           23.0
# 3     7873-325   Patricia Moore  Female         1.0           87.0
# 4     3615-814     Robert Smith  Female        63.0           59.0
# ..         ...              ...     ...         ...            ...
# 595   5093-196    William Moore  Female        18.0           27.0
# 596   1195-163     John Johnson    Male        96.0           75.0
# 597   7098-802  Patricia Miller    Male         1.0           62.0
# 598   2228-122  Elizabeth Brown    Male        65.0           50.0
# 599   2506-967   Linda Williams  Female        13.0           81.0
#
#      science_score  attendance_rate     term
# 0             71.0            74.98  2023_T1
# 1             74.0            83.95  2023_T1
# 2              2.0            78.37  2024_T1
# 3             29.0            60.82  2024_T1
# 4             20.0            68.49  2023_T2
# ..             ...              ...      ...
# 595           39.0            74.76  2023_T1
# 596           14.0            90.05  2023_T1
# 597           28.0            89.99  2024_T1
# 598           74.0            87.15  2023_T1
# 599           50.0            83.95  2023_T1
#
# [600 rows x 8 columns]

# %%
# Feature Engineering
df['gpa'] = df[['math_score', 'english_score', 'science_score']].mean(axis=1)

# %%
df
# Out:
#     student_id        full_name  gender  math_score  english_score  \
# 0     5506-350       Mary Smith    Male        92.0           14.0
# 1     2424-704       Mary Moore  Female        82.0           86.0
# 2     4582-338    James Johnson    Male        99.0           23.0
# 3     7873-325   Patricia Moore  Female         1.0           87.0
# 4     3615-814     Robert Smith  Female        63.0           59.0
# ..         ...              ...     ...         ...            ...
# 595   5093-196    William Moore  Female        18.0           27.0
# 596   1195-163     John Johnson    Male        96.0           75.0
# 597   7098-802  Patricia Miller    Male         1.0           62.0
# 598   2228-122  Elizabeth Brown    Male        65.0           50.0
# 599   2506-967   Linda Williams  Female        13.0           81.0
#
#      science_score  attendance_rate     term        gpa
# 0             71.0            74.98  2023_T1  59.000000
# 1             74.0            83.95  2023_T1  80.666667
# 2              2.0            78.37  2024_T1  41.333333
# 3             29.0            60.82  2024_T1  39.000000
# 4             20.0            68.49  2023_T2  47.333333
# ..             ...              ...      ...        ...
# 595           39.0            74.76  2023_T1  28.000000
# 596           14.0            90.05  2023_T1  61.666667
# 597           28.0            89.99  2024_T1  30.333333
# 598           74.0            87.15  2023_T1  63.000000
# 599           50.0            83.95  2023_T1  48.000000
#
# [600 rows x 9 columns]

# %%
df['risk_score'] = (df['gpa'] < 40).astype(int) + (df['attendance_rate'] < 75).astype(int) * 50

# %%
df
# Out:
#     student_id        full_name  gender  math_score  english_score  \
# 0     5506-350       Mary Smith    Male        92.0           14.0
# 1     2424-704       Mary Moore  Female        82.0           86.0
# 2     4582-338    James Johnson    Male        99.0           23.0
# 3     7873-325   Patricia Moore  Female         1.0           87.0
# 4     3615-814     Robert Smith  Female        63.0           59.0
# ..         ...              ...     ...         ...            ...
# 595   5093-196    William Moore  Female        18.0           27.0
# 596   1195-163     John Johnson    Male        96.0           75.0
# 597   7098-802  Patricia Miller    Male         1.0           62.0
# 598   2228-122  Elizabeth Brown    Male        65.0           50.0
# 599   2506-967   Linda Williams  Female        13.0           81.0
#
#      science_score  attendance_rate     term        gpa  risk_score
# 0             71.0            74.98  2023_T1  59.000000          50
# 1             74.0            83.95  2023_T1  80.666667           0
# 2              2.0            78.37  2024_T1  41.333333           0
# 3             29.0            60.82  2024_T1  39.000000          51
# 4             20.0            68.49  2023_T2  47.333333          50
# ..             ...              ...      ...        ...         ...
# 595           39.0            74.76  2023_T1  28.000000          51
# 596           14.0            90.05  2023_T1  61.666667           0
# 597           28.0            89.99  2024_T1  30.333333           1
# 598           74.0            87.15  2023_T1  63.000000           0
# 599           50.0            83.95  2023_T1  48.000000           0
#
# [600 rows x 10 columns]

# %%
# If attendace rate is greater than or equals to 90: engagement level is high
# If attendance rate is between 75 and 89: engagement level is medium
# If attendance rate is less than 75: engagement level is low
def engagement_level(attendance_rate):
    if attendance_rate >= 90:
        return 'High'
    elif attendance_rate >= 75:
        return 'Medium'
    else:
        return 'Low'

# %%
df['engagement_level'] = df['attendance_rate'].apply(engagement_level)

# %%
df
# Out:
#     student_id        full_name  gender  math_score  english_score  \
# 0     5506-350       Mary Smith    Male        92.0           14.0
# 1     2424-704       Mary Moore  Female        82.0           86.0
# 2     4582-338    James Johnson    Male        99.0           23.0
# 3     7873-325   Patricia Moore  Female         1.0           87.0
# 4     3615-814     Robert Smith  Female        63.0           59.0
# ..         ...              ...     ...         ...            ...
# 595   5093-196    William Moore  Female        18.0           27.0
# 596   1195-163     John Johnson    Male        96.0           75.0
# 597   7098-802  Patricia Miller    Male         1.0           62.0
# 598   2228-122  Elizabeth Brown    Male        65.0           50.0
# 599   2506-967   Linda Williams  Female        13.0           81.0
#
#      science_score  attendance_rate     term        gpa  risk_score  \
# 0             71.0            74.98  2023_T1  59.000000          50
# 1             74.0            83.95  2023_T1  80.666667           0
# 2              2.0            78.37  2024_T1  41.333333           0
# 3             29.0            60.82  2024_T1  39.000000          51
# 4             20.0            68.49  2023_T2  47.333333          50
# ..             ...              ...      ...        ...         ...
# 595           39.0            74.76  2023_T1  28.000000          51
# 596           14.0            90.05  2023_T1  61.666667           0
# 597           28.0            89.99  2024_T1  30.333333           1
# 598           74.0            87.15  2023_T1  63.000000           0
# 599           50.0            83.95  2023_T1  48.000000           0
#
#     engagement_level
# 0                Low
# 1             Medium
# 2             Medium
# 3                Low
# 4                Low
# ..               ...
# 595              Low
# 596             High
# 597           Medium
# 598           Medium
# 599           Medium
#
# [600 rows x 11 columns]

# %%
df.to_csv('../data/processed/engineered_data.csv', index=False)
